# %% [raw]
# ---
# title: "Report: PGS Catalog Calculator Pipeline"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %%
import pandas as pd
import glob

# %%
# Load logs
paths_log = glob.glob("*_summary.csv")
log = pd.concat([pd.read_csv(x) for x in paths_log])

# Load PGS data
paths_pgs = glob.glob("*_pgs.txt.gz")
pgs = pd.concat([pd.read_csv(x, index_col=[0,1], sep='\t') for x in paths_pgs])

# Load PCA/pop sim
paths_popsim = glob.glob("*_popsimilarity.txt.gz")
popsim = pd.concat([pd.read_csv(x, index_col=[0,1], sep='\t') for x in paths_popsim])

# %% [markdown]
# # Pipeline Command

# %%
! cat command.txt
# Out:
# nextflow run /home/sl925/work_calculator/pgsc_calc/main.nf -profile singularity --input /home/sl925/work_calculator/sample_38_HGDP.csv --pgs_id PGS000018,PGS000337,PGS002262,PGS002237,PGS000004,PGS000007,PGS000015,PGS000317,PGS000773,PGS000785,PGS000370,PGS000027,PGS000320,PGS002751,PGS003129,PGS003133,PGS000297,PGS000758,PGS002993,PGS002990 --pgp_id PGP000382 --trait_efo EFO_0004833,EFO_0004612,EFO_0004611,EFO_0004574,EFO_0004530 -c /home/sl925/work_calculator/cardio.config --target_build GRCh38 --min_overlap 0.5 --keep_multiallelic false --ref /home/sl925/work_calculator/pgsc_calc_reference/pgsc_calc.tar.zst --outdir ./r_refscore -w ./work -resume

# %% [markdown]
# # Scoring file metadata
#
# > Additional [documentation](https://pgsc-calc.readthedocs.io/en/latest/output.html#report) is available that explains some of the terms used this report in more detail

# %% [markdown]
# ## Variant matching

# %% [markdown]
# ### Parameters

# %%
! cat params.txt
# Out:
# keep_multiallelic: false
# keep_ambiguous   : false
# min_overlap      : 0.5

# %% [markdown]
# ### Summary

# %%
summary = log.groupby(['dataset', 'accession', 'score_pass', 'match_status'])[['count', 'percent']].sum()
summary
# Out:
#                                                         count    percent
# dataset accession              score_pass match_status
# HGDP    PGS000004_hmPOS_GRCh38 True       excluded         56  17.891374
#                                           matched         237  75.718850
#                                           unmatched        20   6.389776
#         PGS000007_hmPOS_GRCh38 True       excluded        781  20.445026
#                                           matched        2822  73.874346
# ...                                                       ...        ...
#         PGS003404_hmPOS_GRCh38 True       excluded          1  10.000000
#                                           matched           9  90.000000
#         PGS003405_hmPOS_GRCh38 False      excluded          1   0.591716
#                                           matched          84  49.704142
#                                           unmatched        84  49.704142
#
# [533 rows x 2 columns]

# %% [markdown]
# ### Detailed Results

# %%
log
# Out:
#      dataset               accession  score_pass match_status ambiguous  \
# 0       HGDP  PGS000659_hmPOS_GRCh38        True     excluded     False
# 1       HGDP  PGS003141_hmPOS_GRCh38        True     excluded      True
# 2       HGDP  PGS000688_hmPOS_GRCh38        True     excluded     False
# 3       HGDP  PGS002955_hmPOS_GRCh38        True     excluded      True
# 4       HGDP  PGS002669_hmPOS_GRCh38        True     excluded     False
# ...      ...                     ...         ...          ...       ...
# 1534    HGDP  PGS002956_hmPOS_GRCh38        True     excluded      True
# 1535    HGDP  PGS003139_hmPOS_GRCh38        True     excluded      True
# 1536    HGDP  PGS002954_hmPOS_GRCh38        True      matched     False
# 1537    HGDP  PGS002955_hmPOS_GRCh38        True     excluded     False
# 1538    HGDP  PGS002805_hmPOS_GRCh38        True     excluded     False
#
#      is_multiallelic duplicate_best_match duplicate_ID match_flipped  \
# 0              False                False        False         False
# 1               True                 True         True         False
# 2               True                 True        False         False
# 3               True                 True        False         False
# 4               True                 True        False         False
# ...              ...                  ...          ...           ...
# 1534            True                 True        False         False
# 1535           False                False        False         False
# 1536           False                False        False          True
# 1537            True                 True        False         False
# 1538           False                False        False         False
#
#      match_IDs  count    percent
# 0        False      1   0.704225
# 1         True      6   0.166482
# 2        False      2   0.012358
# 3         True    156   0.951626
# 4         True  10732   3.467808
# ...        ...    ...        ...
# 1534     False      6   0.023872
# 1535      True  81992  14.396735
# 1536      True      8   0.000981
# 1537      True    461   2.812176
# 1538     False   1216   0.097630
#
# [1539 rows x 12 columns]

# %% [markdown]
# # Scores
